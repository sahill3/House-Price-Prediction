# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
file_name = "housing.csv"
data = pd.read_csv(file_name)
data.head().style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_7977f_row0_col0 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_7977f_row0_col1, #T_7977f_row0_col7, #T_7977f_row0_col8, #T_7977f_row1_col0, #T_7977f_row1_col3, #T_7977f_row1_col4, #T_7977f_row1_col5, #T_7977f_row1_col6, #T_7977f_row2_col2, #T_7977f_row3_col2, #T_7977f_row4_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7977f_row0_col2 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_7977f_row0_col3, #T_7977f_row0_col4, #T_7977f_row0_col5, #T_7977f_row0_col6, #T_7977f_row1_col2, #T_7977f_row2_col1, #T_7977f_row3_col0, #T_7977f_row3_col1, #T_7977f_row3_col8, #T_7977f_row4_col0, #T_7977f_row4_col1, #T_7977f_row4_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7977f_row1_col1, #T_7977f_row2_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_7977f_row1_col7 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_7977f_row1_col8, #T_7977f_row4_col4 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_7977f_row2_col3, #T_7977f_row2_col8 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_7977f_row2_col4 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_7977f_row2_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_7977f_row2_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_7977f_row2_col7 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_7977f_row3_col3 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_7977f_row3_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_7977f_row3_col5, #T_7977f_row4_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_7977f_row3_col6 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_7977f_row3_col7 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_7977f_row4_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_7977f_row4_col6 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_7977f_row4_col8 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# </style>
# <table id="T_7977f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7977f_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_7977f_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_7977f_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_7977f_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_7977f_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_7977f_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_7977f_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_7977f_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_7977f_level0_col8" class="col_heading level0 col8" >median_house_value</th>
#       <th id="T_7977f_level0_col9" class="col_heading level0 col9" >ocean_proximity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7977f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7977f_row0_col0" class="data row0 col0" >-122.230000</td>
#       <td id="T_7977f_row0_col1" class="data row0 col1" >37.880000</td>
#       <td id="T_7977f_row0_col2" class="data row0 col2" >41.000000</td>
#       <td id="T_7977f_row0_col3" class="data row0 col3" >880.000000</td>
#       <td id="T_7977f_row0_col4" class="data row0 col4" >129.000000</td>
#       <td id="T_7977f_row0_col5" class="data row0 col5" >322.000000</td>
#       <td id="T_7977f_row0_col6" class="data row0 col6" >126.000000</td>
#       <td id="T_7977f_row0_col7" class="data row0 col7" >8.325200</td>
#       <td id="T_7977f_row0_col8" class="data row0 col8" >452600.000000</td>
#       <td id="T_7977f_row0_col9" class="data row0 col9" >NEAR BAY</td>
#     </tr>
#     <tr>
#       <th id="T_7977f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7977f_row1_col0" class="data row1 col0" >-122.220000</td>
#       <td id="T_7977f_row1_col1" class="data row1 col1" >37.860000</td>
#       <td id="T_7977f_row1_col2" class="data row1 col2" >21.000000</td>
#       <td id="T_7977f_row1_col3" class="data row1 col3" >7099.000000</td>
#       <td id="T_7977f_row1_col4" class="data row1 col4" >1106.000000</td>
#       <td id="T_7977f_row1_col5" class="data row1 col5" >2401.000000</td>
#       <td id="T_7977f_row1_col6" class="data row1 col6" >1138.000000</td>
#       <td id="T_7977f_row1_col7" class="data row1 col7" >8.301400</td>
#       <td id="T_7977f_row1_col8" class="data row1 col8" >358500.000000</td>
#       <td id="T_7977f_row1_col9" class="data row1 col9" >NEAR BAY</td>
#     </tr>
#     <tr>
#       <th id="T_7977f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7977f_row2_col0" class="data row2 col0" >-122.240000</td>
#       <td id="T_7977f_row2_col1" class="data row2 col1" >37.850000</td>
#       <td id="T_7977f_row2_col2" class="data row2 col2" >52.000000</td>
#       <td id="T_7977f_row2_col3" class="data row2 col3" >1467.000000</td>
#       <td id="T_7977f_row2_col4" class="data row2 col4" >190.000000</td>
#       <td id="T_7977f_row2_col5" class="data row2 col5" >496.000000</td>
#       <td id="T_7977f_row2_col6" class="data row2 col6" >177.000000</td>
#       <td id="T_7977f_row2_col7" class="data row2 col7" >7.257400</td>
#       <td id="T_7977f_row2_col8" class="data row2 col8" >352100.000000</td>
#       <td id="T_7977f_row2_col9" class="data row2 col9" >NEAR BAY</td>
#     </tr>
#     <tr>
#       <th id="T_7977f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7977f_row3_col0" class="data row3 col0" >-122.250000</td>
#       <td id="T_7977f_row3_col1" class="data row3 col1" >37.850000</td>
#       <td id="T_7977f_row3_col2" class="data row3 col2" >52.000000</td>
#       <td id="T_7977f_row3_col3" class="data row3 col3" >1274.000000</td>
#       <td id="T_7977f_row3_col4" class="data row3 col4" >235.000000</td>
#       <td id="T_7977f_row3_col5" class="data row3 col5" >558.000000</td>
#       <td id="T_7977f_row3_col6" class="data row3 col6" >219.000000</td>
#       <td id="T_7977f_row3_col7" class="data row3 col7" >5.643100</td>
#       <td id="T_7977f_row3_col8" class="data row3 col8" >341300.000000</td>
#       <td id="T_7977f_row3_col9" class="data row3 col9" >NEAR BAY</td>
#     </tr>
#     <tr>
#       <th id="T_7977f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7977f_row4_col0" class="data row4 col0" >-122.250000</td>
#       <td id="T_7977f_row4_col1" class="data row4 col1" >37.850000</td>
#       <td id="T_7977f_row4_col2" class="data row4 col2" >52.000000</td>
#       <td id="T_7977f_row4_col3" class="data row4 col3" >1627.000000</td>
#       <td id="T_7977f_row4_col4" class="data row4 col4" >280.000000</td>
#       <td id="T_7977f_row4_col5" class="data row4 col5" >565.000000</td>
#       <td id="T_7977f_row4_col6" class="data row4 col6" >259.000000</td>
#       <td id="T_7977f_row4_col7" class="data row4 col7" >3.846200</td>
#       <td id="T_7977f_row4_col8" class="data row4 col8" >342200.000000</td>
#       <td id="T_7977f_row4_col9" class="data row4 col9" >NEAR BAY</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# ### Missing Data Analysis

# %%
missing_values = data.isnull().sum()
missing_percentage = (missing_values/len(data)) * 100

print("Missing values:\n", missing_values)
print("\nMissing data Percentage:\n", missing_percentage)
# Out:
# Missing values:
#  longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64
#
# Missing data Percentage:
#  longitude             0.000000
# latitude              0.000000
# housing_median_age    0.000000
# total_rooms           0.000000
# total_bedrooms        1.002907
# population            0.000000
# households            0.000000
# median_income         0.000000
# median_house_value    0.000000
# ocean_proximity       0.000000
# dtype: float64

# %%
data_cleaned = data.dropna()
print("Cleaned:")
print(data_cleaned.isnull().sum())
# Out:
# Cleaned:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# ### Data Exploration and Visualization

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(data_cleaned['median_house_value'], color='forestgreen', kde=True)
plt.title('Distribution of median House Value')
plt.xlabel('House Value')
plt.ylabel('Frequence')
plt.show()

# %%
Q1 = data_cleaned['median_house_value'].quantile(0.25)
print(Q1)
Q3 = data_cleaned['median_house_value'].quantile(0.75)
print(Q3)
IQR = Q3 - Q1


# Define the bounds for the outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
data_no_outliers_1 = data_cleaned[(data_cleaned['median_house_value'] >= lower_bound) & (data_cleaned['median_house_value'] <= upper_bound)]

# Check the shape of the data before and after removal of outliers
print("Original data shape:", data_cleaned.shape)
print("New data shape without outliers:", data_no_outliers_1.shape)
# Out:
# 119500.0
# 264700.0
# Original data shape: (20433, 10)
# New data shape without outliers: (19369, 10)

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(data_no_outliers_1['median_house_value'], color='forestgreen', kde=True)
plt.title('Distribution of median House Value')
plt.xlabel('House Value')
plt.ylabel('Frequence')
plt.show()

# %% [markdown]
# ### Using Box plots for Outlier Detection

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=data_no_outliers_1['median_income'], color='purple')
plt.title('Outlier Analysis in Median Income')
plt.xlabel('Median Income')
plt.show()

# %%
# Calculate Q1 and Q3
Q1 = data_no_outliers_1['median_income'].quantile(0.25)
Q3 = data_no_outliers_1['median_income'].quantile(0.75)
IQR = Q3 - Q1

# Define the bounds for the outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
data_no_outliers_2 = data_no_outliers_1[(data_no_outliers_1['median_income'] >= lower_bound) & (data_no_outliers_1['median_income'] <= upper_bound)]

# Check the shape of the data before and after the removal of outliers
print("Original data shape:", data_no_outliers_1.shape)
print("Data shape without outliers:", data_no_outliers_2.shape)
# Out:
# Original data shape: (19369, 10)
# Data shape without outliers: (19026, 10)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=data_no_outliers_2['median_income'], color='purple')
plt.title('Outlier Analysis in Median Income')
plt.xlabel('Median Income')
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.drop(['ocean_proximity'], axis=1).corr(), annot=True, cmap="Greens")
plt.title('Correlation Heatmap of Housing Data')
plt.show()

# %%
data_no_outliers_2=data_no_outliers_2.drop(['total_bedrooms'], axis=1)
data_no_outliers_2.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# ### String data Categorization to Dummy Variables

# %%
ocean_proximity_dummies = pd.get_dummies(data_no_outliers_2['ocean_proximity'], prefix='ocean_proximity')
data_no_outliers_2 = pd.concat([data_no_outliers_2.drop('ocean_proximity', axis=1), ocean_proximity_dummies], axis=1)
ocean_proximity_dummies
# Out:
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 2                          False                   False
# 3                          False                   False
# 4                          False                   False
# 5                          False                   False
# 6                          False                   False
# ...                          ...                     ...
# 20635                      False                    True
# 20636                      False                    True
# 20637                      False                    True
# 20638                      False                    True
# 20639                      False                    True
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 2                       False                      True
# 3                       False                      True
# 4                       False                      True
# 5                       False                      True
# 6                       False                      True
# ...                       ...                       ...
# 20635                   False                     False
# 20636                   False                     False
# 20637                   False                     False
# 20638                   False                     False
# 20639                   False                     False
#
#        ocean_proximity_NEAR OCEAN
# 2                           False
# 3                           False
# 4                           False
# 5                           False
# 6                           False
# ...                           ...
# 20635                       False
# 20636                       False
# 20637                       False
# 20638                       False
# 20639                       False
#
# [19026 rows x 5 columns]

# %%
data_no_outliers_2.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %% [markdown]
# ### Test Train Split

# %%
X = data_no_outliers_2.drop(['median_house_value'], axis=1)
Y = data_no_outliers_2['median_house_value']
print(X.shape)
print(Y.shape)
# Out:
# (19026, 12)
# (19026,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1111)
print(f"Training split: {x_train.shape[0]}")
print(f"Testing split: {x_test.shape[0]}")
# Out:
# Training split: 15220
# Testing split: 3806

# %% [markdown]
# ### Training

# %%
x_train_const = sm.add_constant(x_train)
x_train_const
# Out:
#        const  longitude  latitude  housing_median_age  total_rooms  \
# 15578    1.0    -116.90     33.03                11.0       3213.0
# 1656     1.0    -121.93     37.89                13.0       2085.0
# 9190     1.0    -118.35     34.32                52.0        102.0
# 11839    1.0    -120.95     39.93                26.0       2023.0
# 12267    1.0    -116.91     33.75                13.0      10886.0
# ...      ...        ...       ...                 ...          ...
# 15355    1.0    -117.32     33.25                 7.0       8206.0
# 9608     1.0    -120.51     37.29                20.0       4927.0
# 12606    1.0    -121.49     38.50                32.0       2364.0
# 2907     1.0    -119.03     35.37                52.0       1503.0
# 18139    1.0    -122.01     37.34                31.0       3080.0
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 15578      1975.0       579.0         3.4750                       True
# 1656        852.0       264.0         7.3445                      False
# 9190         54.0        32.0         1.9875                       True
# 11839       922.0       365.0         2.8125                      False
# 12267      4266.0      1955.0         2.3169                      False
# ...           ...         ...            ...                        ...
# 15355      4399.0      1423.0         3.6301                       True
# 9608       4205.0      1009.0         1.7679                      False
# 12606      1331.0       449.0         3.3190                      False
# 2907        554.0       277.0         1.6786                      False
# 18139      1493.0       582.0         6.3052                       True
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 15578                   False                   False
# 1656                     True                   False
# 9190                    False                   False
# 11839                    True                   False
# 12267                    True                   False
# ...                       ...                     ...
# 15355                   False                   False
# 9608                     True                   False
# 12606                    True                   False
# 2907                     True                   False
# 18139                   False                   False
#
#        ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 15578                     False                       False
# 1656                      False                       False
# 9190                      False                       False
# 11839                     False                       False
# 12267                     False                       False
# ...                         ...                         ...
# 15355                     False                       False
# 9608                      False                       False
# 12606                     False                       False
# 2907                      False                       False
# 18139                     False                       False
#
# [15220 rows x 13 columns]

# %%
model_fitted = sm.OLS(y_train.astype(float), x_train_const.astype(float)).fit()
#ordinary Least Squares OLS
print(model_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     median_house_value   R-squared:                       0.588
# Model:                            OLS   Adj. R-squared:                  0.588
# Method:                 Least Squares   F-statistic:                     1973.
# Date:                Thu, 28 Mar 2024   Prob (F-statistic):               0.00
# Time:                        19:32:08   Log-Likelihood:            -1.8879e+05
# No. Observations:               15220   AIC:                         3.776e+05
# Df Residuals:                   15208   BIC:                         3.777e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                      -1.577e+06   7.19e+04    -21.927      0.000   -1.72e+06   -1.44e+06
# longitude                  -2.268e+04    997.843    -22.728      0.000   -2.46e+04   -2.07e+04
# latitude                   -2.109e+04    981.562    -21.490      0.000    -2.3e+04   -1.92e+04
# housing_median_age           846.4636     44.561     18.996      0.000     759.118     933.809
# total_rooms                   -2.6698      0.716     -3.728      0.000      -4.073      -1.266
# population                   -33.1937      1.050    -31.620      0.000     -35.251     -31.136
# households                   124.3609      4.388     28.343      0.000     115.761     132.961
# median_income               3.562e+04    424.453     83.928      0.000    3.48e+04    3.65e+04
# ocean_proximity_<1H OCEAN  -3.398e+05   1.51e+04    -22.518      0.000   -3.69e+05    -3.1e+05
# ocean_proximity_INLAND     -3.807e+05   1.42e+04    -26.815      0.000   -4.08e+05   -3.53e+05
# ocean_proximity_ISLAND     -1.699e+05   2.88e+04     -5.901      0.000   -2.26e+05   -1.13e+05
# ocean_proximity_NEAR BAY   -3.478e+05   1.55e+04    -22.376      0.000   -3.78e+05   -3.17e+05
# ocean_proximity_NEAR OCEAN -3.388e+05   1.54e+04    -21.928      0.000   -3.69e+05   -3.08e+05
# ==============================================================================
# Omnibus:                     3434.427   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10645.381
# Skew:                           1.157   Prob(JB):                         0.00
# Kurtosis:                       6.381   Cond. No.                     3.13e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.28e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
x_test_const = sm.add_constant(x_test)
test_predictions = model_fitted.predict(x_test_const)

# %% [markdown]
# ### Plotting the Predictions

# %%
plt.scatter(y_test, test_predictions, color = "forestgreen")
plt.xlabel('Observed Values')
plt.ylabel('Predicted Values')
plt.title('Observed vs Predicted Values on Test Data')
plt.plot(y_test, y_test, color='blue', linestyle='--')  
plt.show()

# %%
mean_residuals = np.mean(model_fitted.resid)

print(f"The mean of the residuals is {np.round(mean_residuals,2)}")
# Out:
# The mean of the residuals is 0.0

# %%
plt.scatter(model_fitted.fittedvalues, model_fitted.resid, color = "forestgreen")
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted Values')
plt.show()

# %%
# Calculate the residuals
residuals = model_fitted.resid

# Check for correlation between residuals and each predictor
for column in x_train.columns:
    corr_coefficient = np.corrcoef(x_train[column], residuals)[0, 1]
    print(f'Correlation between residuals and {column}: {np.round(corr_coefficient,2)}')
# Out:
# Correlation between residuals and longitude: -0.0
# Correlation between residuals and latitude: -0.0
# Correlation between residuals and housing_median_age: 0.0
# Correlation between residuals and total_rooms: -0.0
# Correlation between residuals and population: -0.0
# Correlation between residuals and households: -0.0
# Correlation between residuals and median_income: -0.0
# Correlation between residuals and ocean_proximity_<1H OCEAN: 0.0
# Correlation between residuals and ocean_proximity_INLAND: -0.0
# Correlation between residuals and ocean_proximity_ISLAND: 0.0
# Correlation between residuals and ocean_proximity_NEAR BAY: -0.0
# Correlation between residuals and ocean_proximity_NEAR OCEAN: 0.0

# %%
# Plotting the residuals
plt.scatter(model_fitted.fittedvalues, model_fitted.resid, color = "forestgreen")
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted Values')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform it
X_train_scaled = scaler.fit_transform(x_train)

# Apply the same transformation to the test data
X_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt

# Create and fit the model
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)

# Make predictions on the scaled test data
y_pred = lr.predict(X_test_scaled)

# Calculate MSE and RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)

# Output the performance metrics
print(f'RMSE on Test Set: {rmse}')
# Out:
# RMSE on Test Set: 59396.33132460123
